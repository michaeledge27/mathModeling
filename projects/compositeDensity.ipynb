# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeledge27/mathModeling/blob/main/projects/compositeDensity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Introduction

# %% [markdown]
# ![Screenshot 2024-09-19 at 9.58.56 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Work

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
# x = random.random() * 2
# x

# %%
def genRandom():
  y = 0
  x = random.random() * 2
  if x < 1:
    y = x
  else:
    y = -x + 2
  return x, y

# %%
# x, y = genRandom()
# print(f"x = {x} y = {y}")

# %%
smallXList = []
bigXList = []
smallYList = []
bigYList = []
for i in range(1000):
  x, y = genRandom()
  if x < 1:
    smallXList.append(x)
    smallYList.append(y)
  else:
    bigXList.append(x)
    bigYList.append(y)

plt.hist(smallYList, bins=30, color='blue')
plt.hist(bigYList, bins=30, color='red')
plt.show()
